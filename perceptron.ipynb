# %% [markdown]
# Chapter 2. 퍼셉트론

# %%
def AND(x1,x2):
    w1, w2, theta = 0.5,0.5,0.7
    tmp=x1*w1+x2*w2
    if tmp<=theta:
        return 0
    elif tmp>theta:
        return 1

# %%
print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %%
import numpy as np

# %%
x=np.array([0,1])
w=np.array([0.5,0.5])
b=-0.7

print(w*x)
print(np.sum(w*x))
print(np.sum(w*x)+b)
# Out:
# [0.  0.5]
# 0.5
# -0.19999999999999996

# %% [markdown]
# **AND 게이트의 진리표<p>**
# <img src="attachment:1be8b3ec-5e1b-4238-84fd-7a158c0a652d.png" width="400">

# %%
def AND(x1,x2):
    x=np.array([x1,x2])
    w=np.array([0.5,0.5])
    b=-0.7
    tmp=np.sum(w*x)+b
    if tmp<=0:
        return 0
    else:
        return 1

# %% [markdown]
# **NAND 게이트의 진리표**<p>
# <img src="attachment:a44669aa-3bf8-49e1-b1e6-8a9ee8f4baf2.png" width="400">

# %%
def NAND(x1,x2):
    x=np.array([x1,x2])
    w=np.array([-0.5,-0.5])
    b=0.7
    tmp=np.sum(w*x)+b
    if tmp<=0:
        return 0
    else:
        return 1

# %% [markdown]
# **OR 게이트의 진리표**<p>
# <img src="attachment:7d1d3888-6722-484f-ada0-55cf22edff6e.png" width="400">

# %%
def OR(x1,x2):
    x=np.array([x1,x2])
    w=np.array([0.5,0.5])
    b=-0.2
    tmp=np.sum(w*x)+b
    if tmp<=0:
        return 0
    else:
        return 1

# %% [markdown]
# **XOR 게이트의 진리표**<p>
# <img src="attachment:f276a2b0-97f9-4c7c-91a7-2be64914cd68.png" width="400"><p>
# <img src="attachment:87f71480-33c2-4005-93c9-ae18747b4072.png" width="400"><p>
# **XOR의 퍼셉트론**<p>
# <img src="attachment:8b08061c-ab3d-45a0-99f6-5ac9126df27b.png" width="400">

# %%
def XOR(x1,x2):
    s1=NAND(x1,x2)
    s2=OR(x1,x2)
    y=AND(s1,s2)
    return y
